# %%
import pickle
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
data_dict = pickle.load(open('./geohash_to_position_dict.pkl','rb'))
data_point = data_dict.values()
position_array = [list(pos) for pos in data_point]
position_array = np.array(position_array)
X = position_array[:,0]
Y = position_array[:,1]

# %%
print(len(X))
print(len(Y))
plt.scatter(X,Y,alpha=0.5)
plt.show()
# Out:
# 110527
# 110527

# %%
data_list = pickle.load(open('./cluster_center.pkl','rb'))


X_center = data_list[:,0]
Y_center = data_list[:,1]

# %%
print(len(X))
print(len(Y))
plt.scatter(X,Y)
plt.show()
# Out:
# 36
# 36
